# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import tarfile

# %%
username = "harisx91"
path = "Datascience_DAV6150/master/Module_6_Project_1/Data_set/Project1_Eval.csv"
df = pd.read_csv(f'https://raw.githubusercontent.com/{username}/{path}')

# %%
df.head(10)
# Out:
#    IN  TARGET  FixedAcidity  VolatileAcidity  CitricAcid  ResidualSugar  \
# 0   3     NaN           5.4           -0.860        0.27          -10.7
# 1   9     NaN          12.4            0.385       -0.76          -19.7
# 2  10     NaN           7.2            1.750        0.17          -33.0
# 3  18     NaN           6.2            0.100        1.80            1.0
# 4  21     NaN          11.4            0.210        0.28            1.2
# 5  30     NaN          17.6            0.040       -1.15            1.4
# 6  31     NaN          15.5            0.530       -0.53            4.6
# 7  37     NaN          15.9            1.190        1.14           31.9
# 8  39     NaN          11.6            0.320        0.55          -50.9
# 9  47     NaN           3.8            0.220        0.31           -7.7
#
#    Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  Density    pH  Sulphates  \
# 0      0.092               23.0               398.0  0.98527  5.02       0.64
# 1      1.169              -37.0                68.0  0.99048  3.37       1.09
# 2      0.065                9.0                76.0  1.04641  4.61       0.68
# 3     -0.179              104.0                89.0  0.98877  3.20       2.11
# 4      0.038               70.0                53.0  1.02899  2.54      -0.07
# 5      0.535             -250.0               140.0  0.95028  3.06      -0.02
# 6      1.263               10.0                17.0  1.00020  3.07       0.75
# 7     -0.299              115.0               381.0  1.03416  2.99       0.31
# 8      0.076               35.0                83.0  1.00020  3.32       2.18
# 9      0.039               40.0               129.0  0.90610  4.72      -0.64
#
#    Alcohol  LabelAppeal  AcidIndex  STARS
# 0    12.30           -1          6    NaN
# 1    16.00            0          6    2.0
# 2     8.55            0          8    1.0
# 3    12.30           -1          8    1.0
# 4     4.80            0         10    NaN
# 5    11.40            1          8    4.0
# 6     8.50            0         12    3.0
# 7    11.40            1          7    NaN
# 8    -0.50            0         12    NaN
# 9    10.90            0          7    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3335 entries, 0 to 3334
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   IN                  3335 non-null   int64
#  1   TARGET              0 non-null      float64
#  2   FixedAcidity        3335 non-null   float64
#  3   VolatileAcidity     3335 non-null   float64
#  4   CitricAcid          3335 non-null   float64
#  5   ResidualSugar       3167 non-null   float64
#  6   Chlorides           3197 non-null   float64
#  7   FreeSulfurDioxide   3183 non-null   float64
#  8   TotalSulfurDioxide  3178 non-null   float64
#  9   Density             3335 non-null   float64
#  10  pH                  3231 non-null   float64
#  11  Sulphates           3025 non-null   float64
#  12  Alcohol             3150 non-null   float64
#  13  LabelAppeal         3335 non-null   int64
#  14  AcidIndex           3335 non-null   int64
#  15  STARS               2494 non-null   float64
# dtypes: float64(13), int64(3)
# memory usage: 417.0 KB

# %%
import missingno as msno
msno.heatmap(df)

# %%
df.describe()
# Out:
#                  IN  TARGET  FixedAcidity  VolatileAcidity   CitricAcid  \
# count   3335.000000     0.0   3335.000000      3335.000000  3335.000000
# mean    8048.310945     NaN      6.863808         0.310271     0.312429
# std     4655.479037     NaN      6.318431         0.806834     0.870994
# min        3.000000     NaN    -18.200000        -2.830000    -3.120000
# 25%     4018.500000     NaN      5.200000         0.080000     0.000000
# 50%     7906.000000     NaN      6.900000         0.280000     0.310000
# 75%    12061.000000     NaN      9.000000         0.630000     0.605000
# max    16130.000000     NaN     33.500000         3.610000     3.760000
#
#        ResidualSugar    Chlorides  FreeSulfurDioxide  TotalSulfurDioxide  \
# count    3167.000000  3197.000000        3183.000000         3178.000000
# mean        5.319135     0.061425          34.947063          123.410478
# std        34.370614     0.313969         149.633473          225.799833
# min      -128.300000    -1.150000        -563.000000         -769.000000
# 25%        -2.600000     0.016000           3.000000           27.250000
# 50%         3.600000     0.047000          30.000000          124.000000
# 75%        17.200000     0.171000          79.250000          210.000000
# max       145.400000     1.263000         617.000000         1004.000000
#
#            Density           pH    Sulphates      Alcohol  LabelAppeal  \
# count  3335.000000  3231.000000  3025.000000  3150.000000  3335.000000
# mean      0.994670     3.236518     0.534592    10.583632     0.013493
# std       0.026191     0.675559     0.905347     3.758877     0.888572
# min       0.889750     0.600000    -3.070000    -4.200000    -2.000000
# 25%       0.988305     2.980000     0.330000     9.000000    -1.000000
# 50%       0.994600     3.210000     0.500000    10.400000     0.000000
# 75%       1.000525     3.490000     0.820000    12.500000     1.000000
# max       1.099830     6.210000     4.180000    25.600000     2.000000
#
#          AcidIndex        STARS
# count  3335.000000  2494.000000
# mean      7.747826     2.040096
# std       1.315420     0.913418
# min       5.000000     1.000000
# 25%       7.000000     1.000000
# 50%       8.000000     2.000000
# 75%       8.000000     3.000000
# max      17.000000     4.000000

# %%
value_counts = df.TARGET.value_counts()
counts = value_counts.values
labels = value_counts.index
plt.bar(x = labels, height = counts, tick_label = labels)
# Out:
# <BarContainer object of 0 artists>

# %%
df.FixedAcidity.hist()
